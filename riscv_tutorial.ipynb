# %% [markdown]
# ![google_forms_rv_ctb2023_banner.jpg](data:image/jpeg;base64,...)
#
# ---
# ## **1.   RISC-V Introduction**
# ---
#
# The video provides an Introduction to RISC-V ISA

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ZDa-Z5JzLYM')
